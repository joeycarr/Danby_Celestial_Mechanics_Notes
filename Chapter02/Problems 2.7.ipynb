# %% [markdown]
# # Problems 2.7
#
# $$
#     \newcommand{\uvec}[1]{\hat{\mathbf{#1}}}
#     \newcommand{\dvec}[1]{\dot{\vec{#1}}}
#     \newcommand{\ddvec}[1]{\ddot{\vec{#1}}}
# $$

# %% [markdown]
# 1. What conditions are necessary for $\ddot r = |\ddvec{r}|$?

# %% [markdown]
# 2. If $P$ moves in a plane and its areal velocity about $O$ is constant, show that the transverse acceleration of $P$ is zero.

# %% [markdown]
# 3. Solve the simultaneous equations
#
#     $$ \ddot r - r \dot\theta^2 = 0 \quad \rm{and} \quad 2\dot r \dot\theta + r\ddot\theta = 0 $$
#
#     What can be deduced from these?

# %% [markdown]
# 4. A particle moves in an ellipse with semiaxes $a$ and $b$, with constant areal velocity $A$ about the center of the ellipse. Find the components of its velocity and acceleration in cartesian and polar coordinates. Find also the period of the orbit.
