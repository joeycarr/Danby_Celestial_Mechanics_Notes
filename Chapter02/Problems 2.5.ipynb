# %% [markdown]
# # Problems 2.5
#
# $$
#     \newcommand{\uvec}[1]{\hat{\mathbf{#1}}}
#     \newcommand{\dvec}[1]{\dot{\vec{#1}}}
#     \newcommand{\ddvec}[1]{\ddot{\vec{#1}}}
# $$

# %% [markdown]
# 1. Solve the following equations of motion, and interpret their solutions.
#
#     <p style="text-align: center">
#     (a) $\dvec r = \vec a \quad$
#     (b) $\dvec r = b \quad$
#     (c) $\vec r \times \dvec r = 0 \quad$
#     (d) $\vec r \cdot \dvec r = c \quad$
#     <br />
#     (e) $|\dvec r| = \dot r \quad$
#     (f) $\vec r \times \ddvec r = 0 \quad $
#     (g) $\dvec r = \vec r \times \ddvec r$.
#     </p>

# %% [markdown]
# 2. Show that $\frac{d(a\vec r)}{dt} = \vec r \frac{da}{dt} + a \frac{d\vec r}{dt}$.

# %% [markdown]
# 3. Show that $\frac{d(\vec a \cdot \vec b)}{dt} = \vec a \cdot \frac{d\vec b}{dt} + \vec b \cdot \frac{d\vec a}{dt}$.

# %% [markdown]
# 4. Show that $\frac{d(\vec a \times \vec b)}{dt} = \vec a \times \frac{d\vec b}{dt} + \frac{d\vec a}{dt} \times \vec b$.

# %% [markdown]
# 5. Describe the hodograph of uniform circular motion with radius $a$ and speed $v$. Hence show that the acceleration is $(v^2/a)$ directed toward the center.

# %% [markdown]
# 6. A particle describes an equiangular spiral with constant areal velocity $A$. Show that for the motion $r\dot r = 2A\cot \theta$, where $\theta$ is the (constant) angle between the radius vector and the tangent, and solve this equation to show how $r$ varies with the time.
