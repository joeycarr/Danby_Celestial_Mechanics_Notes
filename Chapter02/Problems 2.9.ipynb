# %% [markdown]
# # Problem 2.9
#
# $$
#     \newcommand{\uvec}[1]{\hat{\mathbf{#1}}}
#     \newcommand{\dvec}[1]{\dot{\vec{#1}}}
#     \newcommand{\ddvec}[1]{\ddot{\vec{#1}}}
# $$

# %% [markdown]
# Using the triangle $PNX$, derive expressions for $\alpha$, and $\delta$ in terms of $\lambda$ and $\beta$. Check these expressions, using the alternative method indicated above.
