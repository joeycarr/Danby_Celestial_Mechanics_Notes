# %% [markdown]
# # Problems 2.3
#
# $$ \newcommand{\uvec}[1]{\hat{\mathbf{#1}}} $$

# %% [markdown]
# 1. If the angle between $\vec{AB}$ and $\vec{CD}$ is $\theta$, what are the angles between $\vec{AB}$ and $\vec{DC}$ and between $\vec{BA}$ and $\vec{DC}$?
#
#     <img src="Problems_2.3.1.svg" />
#
#     We don't need any algebra or trigonometry here, it's just a matter of inspecting the diagram. The angle between $\vec{AB}$ and $\vec{DC}$ is a half rotation plus $\theta$, i.e. $\pi+\theta$ radians. The angle between $\vec{BA}$ and $\vec{DC}$ is exactly equal to $\theta$ itself.

# %% [markdown]
# 2. Find a formula for the cosine of the angle between the two vectors $(x_1, y_1, z_1)$ and $(x_2, y_2, z_2)$.
#
#     Given that
#
#     $$ \vec A \cdot \vec B = \Vert\vec A\Vert\ \Vert\vec B\Vert\cos{\theta} $$
#
#     And that
#
#     $$ \vec A \cdot \vec B = x_A x_B + y_A y_B + z_A + z_B $$
#
#     If we set $\vec A = (x_1, y_1, z_1)$ and $\vec B = (x_2, y_2, z_2)$, then we have
#
#     $$ \Vert\vec A\Vert\ \Vert\vec B\Vert\cos{\theta} = x_1 x_2 + y_1 y_2 + z_1 z_ 2 $$
#
#     Dividing both sides by the product of the magnitudes of $\vec A$ and $\vec B$, we have
#
#     $$ \cos \theta = \frac{x_1 x_2 + y_1 y_2 + z_1 z_ 2}{\Vert\vec A\Vert\ \Vert\vec B\Vert} $$
#
#     Which we can fully expand to
#
#     $$ \cos \theta = \frac{x_1 x_2 + y_1 y_2 + z_1 z_ 2}{\sqrt{x_1^2 + y_1^2 + z_1^2}\sqrt{x_2^2 + y_2^2 + z_2^2}} $$
#
#     Or, if we want to retain vector form, we might never have expanded the numerator
#
#     $$ \cos \theta = \frac{\vec A \cdot \vec B}{\Vert\vec A\Vert\ \Vert\vec B\Vert} $$

# %% [markdown]
# 3. Prove by a vector method that for any triangle
#
#     $$ a^2 = b^2 + c^2 - 2bc\cos A $$
#
#     This makes sense when $A = \pi / 2$, then $\cos A = 0$ and the third term is eliminated; the result is something that looks very much like the pythagorean theorem, although the hypotenuse is labeled $a$ rather than $c$.
#
#     <img src="Problems_2.3.3.svg" style="max-width: 70%;" />
#
#     We'll invent vectors $\vec a, \vec b, and \vec c$ that have length $a = \Vert\vec a\Vert$, $b = \Vert\vec b\Vert$, and $c = \Vert\vec c\Vert$. Each angle, $A$, $B$, and $C$ is opposite the side with the corresponding lowercase letter. I imagine that Danby expects us to be familiar with this formula, which goes by the name "the law of cosines", and to recall that this is the canonical labeling.
#
#     I "cheated" and just looked up the answer on Wikipedia, which has a large listing of proofs of the law of cosines, including one [using vectors](https://en.wikipedia.org/wiki/Law_of_cosines#Using_vectors).
#
#     We start by noting that
#
#     $$ \vec a = \vec c - \vec b $$
#
#     Since we can take the dot product of each side with itself and continue to have a balanced equation, analogous to squaring each side of an equation, we can rewrite this identity for $\vec c$ as
#
#     $$ \vec a \cdot \vec a = (\vec b - \vec c)\cdot(\vec b - \vec c) $$
#
#     Recall the defining identity of the dot product, which we'll restate here using $\vec u$ and $\vec v$ to avoid confusion
#
#     $$ \vec u \cdot \vec v = \Vert\vec u\Vert\ \Vert\vec v\Vert \cos\theta $$
#
#     When the dot product is taken with itself, the $\cos \theta$ term is $\cos(\pi / 2)$, which equals $1$, so the result is the magnitude of the input vector squared. If we expand the right-hand side like any polynomial multiplication, using the _first inner outer last_ (FOIL) mnemonic. This allows us to restate the above as
#
#     $$ \Vert\vec a\Vert^2 = \Vert\vec b\Vert^2 + \Vert\vec c\Vert^2 + 2(\vec b \cdot \vec c) $$
#
#     Or more simply using the scalars that correspond to the similarly labeled vectors:
#
#     $$ a^2 = b^2 + c^2 + 2(\vec b \cdot \vec c) $$
#
#     We still have an unresolved dot product, but again we can apply the defining identity of the dot product to obtain
#
#     $$ a^2 = b^2 + c^2 + 2(\Vert\vec b\Vert\ \Vert\vec c\Vert\cos A) $$
#
#     Again, subsitituting the simple scalars for the magnitude expressions, we finally obtain the expression that Danby asked us to prove
#
#     $$ a^2 = b^2 + c^2 + 2bc\cos A $$

# %% [markdown]
# 4. Solve, for the unknown vector $\vec x$, the equations:
#
#     (a) $\vec x \cdot \vec a = 0$
#
#     (b) $\vec x \cdot \vec a = \vec x \cdot \vec b$ (where $\vec a \ne \vec b$)
#
#     (c) $\vec x \cdot \vec a = b$

# %% [markdown]
# ---
# (a) $\vec x \cdot \vec a = 0 $
#
# We know that $\cos \theta = $ when $\theta = \pi/2$, i.e. when the vectors are at right angles. So given an unknown vector $\vec x$ and a constant vector $\vec a$, their dot product equalling zero signifies a plane at the root of $\vec a$, where all points in the plane are given by $\vec x$.
#
# If we take it as given that a plane can be defined implicitly as
#
# $$ Ax + By + Cz + D = 0 $$
#
# Then we can see that the expansion of the dot product looks like a plane. Here the coefficients are $A = a_x$, $B = a_y$, $C = a_z$, and $D = 0$.
#
# $$ \vec x \cdot \vec a = x_x a_x + x_y a_y + x_z a_z = 0 $$
#
# I think the best we can hope for is an expression for $\vec x$ in terms of its components, although I'd hesitate to call this a solution.
#
# $$ \begin{align}
#     \vec x &= (x_x, x_y, x_z) \\
#     \vec x &= \left(-\frac{x_ya_y + x_za_z}{a_x}, -\frac{x_xa_x + x_za_z}{a_y}, -\frac{x_xa_x + x_ya_y}{a_z}\right)
#     \end{align}
# $$

# %% [markdown]
# If we go with geometric algebra instead, we can instead add $\vec x \wedge \vec a$ to both sides
#
# $$ \begin{align}
#     \vec x \cdot \vec a &= 0 \\
#     \vec x \cdot \vec a + \vec x \wedge \vec a &= \vec x \wedge \vec a \\
#     \vec x \vec a &= \vec x \wedge \vec a \\
#     \vec x \vec a \vec a^{-1} &= (\vec x \wedge \vec a)a^{-1} \\
#     \vec x &= (\vec x \wedge \vec a)a^{-1}
#     \end{align}
# $$
#
# I don't think that $(\vec x \wedge \vec a)a^{-1}$ is meaningful because $\vec x \wedge \vec a$ is a bivector quantity, and I think $\vec a^{-1}$ is a normal vector. There's no meaningful product procedure to combine a bivector and a vector.

# %% [markdown]
# (b) $\vec x \cdot \vec a = \vec x \cdot \vec b $ (where $\vec a \ne \vec b$)
#
# Probably the only thing I can speak to here is the geometric interpretation. If we use the rationale from (c), to establish that $\vec x cdot \vec a$ equaling a non-zero scalar value is an implicit equation for the surface of a regular cone, then the place where two arbitrarily oriented cones share a common solution must be an ellipse.

# %% [markdown]
# (c) $\vec x \cdot \vec a = b$
#
# If we say that all $\vec x$ that satisfy the equation are on the surface, and all $\vec x$ that do not satisfy the equation are not on the surface, then this equation describes a cone with an interior angle proportional to the scalar value $b$. The cone will be a surface of rotation around $\vec a$. In the case where $b = 0$, the cone flattens completely into a plane.

# %% [markdown]
# 5. Evaluate $(\vec a + \vec b) \cdot (\vec a - \vec b)$ when $a = b$. Hence prove that the diagonals of a rhombus are perpendicular.

# %% [markdown]
# 6. $\vec a$, $\vec b$, and $\vec c$ are three nonzero and co-planar vectors, and no two of them are parallel or antiparallel. Show that if
#
#     $$ \vec x \cdot \vec a = \vec x \cdot \vec b = \vec x \cdot \vec c = 0 $$
#
#     then $\vec x = 0$.

# %% [markdown]
# 7. Assuming that forces are vectors, what relation must exist between $P$ and $Q$ such that the forces $P$ along $(1, 0, 0)$ and $Q$ along $(0, 1, 0)$ have zero resultant along $(l, m, 0)$?

# %% [markdown]
# 8. Show by a vector method that the altitudes of a triangle intersect in a point.

# %% [markdown]
# 9. Show by a vector method that the perpendicular bisectors of a triangle intersect in a point.

# %% [markdown]
# 10. Show that the equation of a plane can be written
#
#     $$ (\vec r - \vec r_0) \cdot \uvec i = 0 $$
#
#     Interpret $\uvec i$, and show that this equation is equivalent to that of problem 12, Section 2.2.

# %% [markdown]
# 11. Find the shortest distances from the origin to the line
#
#     $$ \vec r = \vec r_0 + \lambda\uvec i $$
#
#     and to the plane
#
#     $$ (\vec r - \vec r_0) \cdot \uvec i = 0 $$

# %% [markdown]
# 12. Find the shortest distances from the point $P_1$, where $\vec{OP_1} = \vec r_1$, to the line and plane of problem 11.

# %% [markdown]
# 13. Interpret the equation
#
#     $$ (\vec r - \vec r_0)^2 = a^2 $$
#
#     where $\vec r$ is a variable vector.
